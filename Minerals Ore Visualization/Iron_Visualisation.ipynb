# %% [markdown]
# # MINERR.AI
# ## TRACING THE UNDISCOVERED
#
# ## VISUALIZATION OF IRON ORE
#
# You can download the dataset from <a href="https://data.gov.in/catalog/location-iron-ore-deposits-india-and-its-salient-features">here</a>.
#
#                                                                                                            by Code O Holics

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Iron_Ore.csv')

# %%
data.head()
# Out:
#                  METALLOGENESIS             LOCALITY        STATE TOPOSHEET  \
# 0               BABABUDAN RANGE  ATTIGUNDI-GALLIKERA    KARNATAKA      48 O
# 1               BABABUDAN RANGE         KEMMANAGUNDI    KARNATAKA      48 O
# 2                BAILADILA BELT            BAILADILA  CHATTISGARH      65 F
# 3  BELLARY (SANDUR SCHIST BELT)           OBULAPURAM    KARNATAKA      57 A
# 4         BONAI-BADAMPAHAR BELT            BADAMGARH       ORISSA      73 G
#
#      LATITUDE   LONGITUDE      LATDD      LONDD COMMODITY  \
# 0     13 25 N     75 45 E  13.416667  75.750000      Iron
# 1  13 32-33 N     75 45 E  13.533333  75.750000      Iron
# 2  18 40-50 N  81 11-14 E  18.666667  81.183333      Iron
# 3  15 04 15 N  76 50 20 E  15.070833  76.838889      Iron
# 4      21 48N      85 16E  21.800000  85.266667      Iron
#
#                            HOSTROCK              MORPHOGENESIS  \
# 0      BHQ,METAPELITE,METAVOLCANICS  VOLCANOSEDIMENTARY-BEDDED
# ...

# %%
data = data.drop(['LATITUDE','LONGITUDE'], axis = 1)

# %%
data.isna().sum()
# Out:
# METALLOGENESIS    0
# LOCALITY          0
# STATE             0
# TOPOSHEET         0
# LATDD             0
# LONDD             0
# COMMODITY         0
# HOSTROCK          0
# MORPHOGENESIS     0
# FORMATION         0
# dtype: int64

# %%
data['METALLOGENESIS'].value_counts()
# Out:
# BONAI-NOAMUNDI-JAMDA PROVINCE              10
# BONAI-BADAMPAHAR BELT                       5
# CHITRADURGA BELT                            5
# GARUMAHISANI PROVINCE                       5
# KANJAMALLAI-ATTUR  BELT                     5
# GARUMAHISANI PROVINCE (RAIRANGPUR BELT)     4
# NEB(SANDUR SCHIST BELT)                     3
# CHIRIA-MANOHARPUKUR SECTOR                  3
# NEB (SANDUR SCHIST BELT)                    3
# NOAMUNDI-JAMDA SECTOR                       2
# WESTERN GHAT BELT                           2
# SHIMOGA BELT                                2
# SATYAMANGALAM-AJJUR(GRANULITE) BELT         2
# SANDUR-KUMARSWAMI-DONIMALAI RANGE           2
# SANDUR BELT-BTV RANGE                       2
# BABABUDAN RANGE                             2
# BONAI-KEONJHAR RANGE BELT                   2
# BONAI-NOAMUNDI-JAMDA BELT                   2
# DALLI-RAJHARA BELT                          2
# NEB RANGE(SANDUR BELT)                      1
# ...

# %%
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('RAMGIRI-P NAKACHERLA-HUNGUD BELT','RAMAGIRI-PENAKACHERLA-HUNGUD BELT',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('RAMGIRI-P AKACHERLA-HUNGUD BELT\n','RAMAGIRI-PENAKACHERLA-HUNGUD BELT',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('NEB RANGE(SANDUR BELT)','SANDUR SCHIST BELT-NEB RANGE',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('NEB RANGE (SANDUR SCHIST BELT)','SANDUR SCHIST BELT-NEB RANGE',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('BONAI-NOAMUNDI-JAMDA PROVINCE','BONAI-NOAMUNDI-JAMDA BELT',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('WURRYA HILL RANGE(?)','WURRYA HILL RANGE',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('PUR BANERA BELT(EASTERN ZONE)','PUR-BANERA BELT(EASTERN ZONE)',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('RAMANDUR RANGE(SHIMOGA SCHIST) BELT','SHIMOGA SCHIST BELT(RAMANDUR RANGE)',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('KAPPALGUDDA (SHIMOGA SCHIST) BELT','SHIMOGA SCHIST BELT(KAPPALGUDDA RANGE)',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('PUR-BANERA BELT (WESTERN ZONE)','PUR-BANERA BELT(WESTERN ZONE)',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('NEB(SANDUR SCHIST BELT)','SANDUR SCHIST BELT-NEB RANGE',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('NEB (SANDUR SCHIST BELT)','SANDUR SCHIST BELT-NEB RANGE',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('BELLARY (SANDUR SCHIST BELT)','SANDUR SCHIST BELT-BELLARY',regex=False)
data["METALLOGENESIS"]=data["METALLOGENESIS"].str.replace('SANDUR BELT-BELLARY SECTOR','SANDUR SCHIST BELT-BELLARY',regex=False)

# %%
print(data['METALLOGENESIS'].value_counts().to_string())
# Out:
# BONAI-NOAMUNDI-JAMDA BELT                  12
# SANDUR SCHIST BELT-NEB RANGE                9
# BONAI-BADAMPAHAR BELT                       5
# CHITRADURGA BELT                            5
# GARUMAHISANI PROVINCE                       5
# KANJAMALLAI-ATTUR  BELT                     5
# GARUMAHISANI PROVINCE (RAIRANGPUR BELT)     4
# CHIRIA-MANOHARPUKUR SECTOR                  3
# SANDUR BELT-BTV RANGE                       2
# SATYAMANGALAM-AJJUR(GRANULITE) BELT         2
# SHIMOGA BELT                                2
# NOAMUNDI-JAMDA SECTOR                       2
# BABABUDAN RANGE                             2
# WESTERN GHAT BELT                           2
# SANDUR-KUMARSWAMI-DONIMALAI RANGE           2
# DALLI-RAJHARA BELT                          2
# BONAI-KEONJHAR RANGE BELT                   2
# SANDUR SCHIST BELT-BELLARY                  2
# SHIMOGA SCHIST BELT                         1
# SATYAMANGLAM-AJJUR BELT                     1
# ...

# %%
print(data['LOCALITY'].value_counts().to_string())
# Out:
# NOTABURU                        2
# ATTIGUNDI-GALLIKERA             1
# INGILIGI                        1
# MALANGTOLI                      1
# VENUMBAKA-RASANUR               1
# SANKALAPURAM                    1
# SANDUR                          1
# KARADIKOLLA                     1
# JAISINGPUR                      1
# PAPINAYAKANAHALLI               1
# NUGGIHALLI                      1
# MADERAHALLI                     1
# KARINAGUR                       1
# KAPPALGUDDA                     1
# VALAYAPATHI-TATTAYANGIPETTAI    1
# KANJAMALAI                      1
# CHITTORI-TAINANDAMALAI          1
# ATTUR                           1
# NUIA                            1
# RAMANDURG                       1
# RAIRANGPUR                      1
# AJJUR                           1
# KUDERMUKH                       1
# BALLALAYAYANADURG               1
# JAYAPURA                        1
# KOTEBARA                        1
# DONI                            1
# ...

# %%
print(data['STATE'].value_counts().to_string())
# Out:
# KARNATAKA         31
# ORISSA            24
# JHARKHAND          8
# TAMILNADU          8
# CHATTISGARH        4
# ANDHRA PRADESH     1
# ORISSA (?)         1
# KARNATAKA, A.P     1
# MAHARASTRA         1

# %%
data["STATE"]=data["STATE"].str.replace('ORISSA (?)','ORISSA',regex=False)
data["STATE"]=data["STATE"].str.replace('KARNATAKA, A.P','KARNATAKA',regex=False)

# %%
print(data['STATE'].value_counts().to_string())
# Out:
# KARNATAKA         32
# ORISSA            25
# JHARKHAND          8
# TAMILNADU          8
# CHATTISGARH        4
# ANDHRA PRADESH     1
# MAHARASTRA         1

# %%
print(data['TOPOSHEET'].value_counts().to_string())
# Out:
# 57 A          17
# 73 F          16
# 73 J           9
# 73 G           8
# 48 O           5
# 58 I           4
# 57 C           3
# 57 B           3
# 58 A           2
# 48 I           2
# 65 E           1
# 48 K           1
# 58 E           1
# 57 A, 57 B     1
# 57 L           1
# 57 N           1
# 65 F           1
# 64 D           1
# 64 H           1
# 65 A           1

# %%
data['TOPOSHEET'] = data['TOPOSHEET'].str.replace('57B','57 B', regex = False)

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(data, title="Iron Ore Report", explorative=True)

# %%
profile.to_file("iron-report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# !pip install folium

# %%
from geopy.geocoders import Nominatim
import folium
import re
import json
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
from sklearn.cluster import KMeans

# %%
latitude = 13.416667
longitude = 75.750000

# %%
data["NEW"] = "Ore: "+data["COMMODITY"]+" | Locality: "+data["LOCALITY"]

# %%
data["NEW"]
# Out:
# 0     Ore: Iron | Locality: ATTIGUNDI-GALLIKERA
# 1            Ore: Iron | Locality: KEMMANAGUNDI
# 2               Ore: Iron | Locality: BAILADILA
# 3              Ore: Iron | Locality: OBULAPURAM
# 4               Ore: Iron | Locality: BADAMGARH
#                         ...
# 74               Ore: Iron | Locality: KOTEBARA
# 75               Ore: Iron | Locality: JAYAPURA
# 76      Ore: Iron | Locality: BALLALAYAYANADURG
# 77              Ore: Iron | Locality: KUDERMUKH
# 78              Ore: Iron | Locality: SURJAGARH
# Name: NEW, Length: 79, dtype: object

# %%
data = data.drop('COMMODITY', axis = 1)

# %%
map_india = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(data['LATDD'], data['LONDD'], data['NEW']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_india)

# %%
map_india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data = data.drop(["NEW"],axis=1)

# %%
map_html = map_india._repr_html_()

# %%
print(map_html)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# PCA
# Not Successfull as gives the result only 2 Features are important....

# %%
data.head()
# Out:
#                METALLOGENESIS             LOCALITY        STATE TOPOSHEET  \
# 0             BABABUDAN RANGE  ATTIGUNDI-GALLIKERA    KARNATAKA      48 O
# 1             BABABUDAN RANGE         KEMMANAGUNDI    KARNATAKA      48 O
# 2              BAILADILA BELT            BAILADILA  CHATTISGARH      65 F
# 3  SANDUR SCHIST BELT-BELLARY           OBULAPURAM    KARNATAKA      57 A
# 4       BONAI-BADAMPAHAR BELT            BADAMGARH       ORISSA      73 G
#
#        LATDD      LONDD                          HOSTROCK  \
# 0  13.416667  75.750000      BHQ,METAPELITE,METAVOLCANICS
# 1  13.533333  75.750000      BHQ,METAPELITE,METAVOLCANICS
# 2  18.666667  81.183333      BHQ,METAPELITE,METAVOLCANICS
# 3  15.070833  76.838889                SHALE,PHYLLITE,BHQ
# 4  21.800000  85.266667  BHQ,SHALE INTERLAYERED WITH LAVA
#
#                MORPHOGENESIS           FORMATION
# 0  VOLCANOSEDIMENTARY-BEDDED      BABABUDAN Sgp.
# 1  VOLCANOSEDIMENTARY-BEDDED        DHARWAR Sgp.
# ...

# %%
data["STATE"].value_counts()
# Out:
# KARNATAKA         32
# ORISSA            25
# JHARKHAND          8
# TAMILNADU          8
# CHATTISGARH        4
# ANDHRA PRADESH     1
# MAHARASTRA         1
# Name: STATE, dtype: int64

# %%
# 5 States have highest according to the data so we will be creating

# %%
data = data.drop("FORMATION",axis=1)

# %%
features = data[['LATDD', 'LONDD']]
print(features)
# Out:
#         LATDD      LONDD
# 0   13.416667  75.750000
# 1   13.533333  75.750000
# 2   18.666667  81.183333
# 3   15.070833  76.838889
# 4   21.800000  85.266667
# ..        ...        ...
# 74  13.883333  74.816667
# 75  13.466667  75.400000
# 76  13.266667  75.400000
# 77  13.283333  75.250000
# 78  19.616667  80.350000
#
# [79 rows x 2 columns]

# %%
## PREVENTING MEMORY LEAKAGE

# %%
from sklearn.cluster import KMeans
# create kmeans model/object
kmeans = KMeans(
    init="random",
    n_clusters=5,
    n_init=10,
    max_iter=300,
    random_state=42
)

# %%
kmeans.fit(features)
# save results
labels = kmeans.labels_
# Out:
# C:\Users\Deeshu\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data['cluster'] = labels

# %%
data.head(10)
# Out:
#                METALLOGENESIS                   LOCALITY        STATE  \
# 0             BABABUDAN RANGE        ATTIGUNDI-GALLIKERA    KARNATAKA
# 1             BABABUDAN RANGE               KEMMANAGUNDI    KARNATAKA
# 2              BAILADILA BELT                  BAILADILA  CHATTISGARH
# 3  SANDUR SCHIST BELT-BELLARY                 OBULAPURAM    KARNATAKA
# 4       BONAI-BADAMPAHAR BELT                  BADAMGARH       ORISSA
# 5       BONAI-BADAMPAHAR BELT           BALIA-KHEJURDARI       ORISSA
# 6       BONAI-BADAMPAHAR BELT  FULIHARI-KURMITAR-SILJORA       ORISSA
# 7       BONAI-BADAMPAHAR BELT                      KALTA       ORISSA
# 8       BONAI-BADAMPAHAR BELT                 MANKAMACHA       ORISSA
# 9   BONAI-KEONJHAR RANGE BELT                  KHANDBAND       ORISSA
#
#   TOPOSHEET      LATDD      LONDD                          HOSTROCK  \
# 0      48 O  13.416667  75.750000      BHQ,METAPELITE,METAVOLCANICS
# ...

# %%
data['LOC']=data["LATDD"].astype(str) +", "+data["LONDD"].astype(str)

# %%
# display the number of mamber each clustering
_clusters = data.groupby('cluster')["STATE"].count()
print(_clusters)
# Out:
# cluster
# 0    20
# 1    12
# 2     5
# 3     9
# 4    33
# Name: STATE, dtype: int64

# %%
colors = ['red', 'blue', 'green', 'purple', 'gray']
lat = data.iloc[0]['LATDD']
lng = data.iloc[0]['LONDD']

map = folium.Map(location=[lng, lat], zoom_start=8)
for lat, lng, cluster,label in zip(data['LATDD'], data['LONDD'], data['cluster'],data['LOC']):
# for _, row in data.iterrows():
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        location=[lat, lng],
        popup=label,
        radius=15, 
        weight=2, 
        fill=True, 
        fill_color=colors[cluster],
        color=colors[cluster]
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map_cluster = map._repr_html_()

# %%
print(map_cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
